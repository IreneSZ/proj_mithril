# %%
import plotly
plotly.tools.set_credentials_file(username='IreneZ', api_key='3m6nNUqf3IhzgjZeJO9q')

import plotly.plotly as py
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ivv_normal.csv')
df['close'] = (df['close']-df['close'].mean())/df['close'].std()
df.head()
# Out:
#    Unnamed: 0      date       low      high     close    volume      open  \
# 0         200  20010307 -0.439921 -0.455396 -0.439732 -0.669027 -0.438876
# 1         201  20010308 -0.429719 -0.447085 -0.432197 -1.015534 -0.439084
# 2         202  20010309 -0.494888 -0.480540 -0.502452 -0.244510 -0.468421
# 3         203  20010312 -0.609195 -0.550982 -0.618320 -0.285677 -0.534586
# 4         204  20010313 -0.615233 -0.596905 -0.578815 -1.009871 -0.601999
#
#    close-open  close-open_%of_close  high-low  high-low_%of_close      macd  \
# 0   -0.124481             -0.119906 -0.293656           -0.254819 -1.713257
# 1    0.174580              0.180720 -0.327246           -0.289116 -1.572642
# 2   -1.430906             -1.471366  0.240059            0.297527 -1.636192
# 3   -3.406283             -3.679961  1.023836            1.177954 -1.982363
# 4    0.670392              0.718906  0.307240            0.396222 -2.125731
#
#         rsi   50d_avg  100d_avg  200d_avg        so
# ...

# %%
df = df[['close','200d_avg','100d_avg']][200:]

# %%
x1 = np.asarray(df['close'])
x2 = np.asarray(df['100d_avg'])
x3 = np.asarray(df['200d_avg'])


hist_data = [x1, x2, x3]

group_labels = ['close price', '100 day moving average price','200 day moving average price']
colors = ['#A56CC1', '#A6ACEC', '#63F5EF']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=.02, show_rug=False)

# Add title
fig['layout'].update(title='Hist and Curve Plot: Selected Variables (Normalized)')

# Plot!
py.iplot(fig, filename='Hist and Curve')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~IreneZ/137.embed" height="525px" width="100%"></iframe>
